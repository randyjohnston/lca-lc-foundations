# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="ollama:gemma4:e4b"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response['messages'][-1].content)
# Out:
# My knowledge is based on the massive dataset I was trained on. Therefore, while I have access to a vast amount of information, my training data includes knowledge up to a certain cutoff date.
#
# **I do not have real-time knowledge of events that have occurred after my last training update.**
#
# If you are asking about a very recent event, piece of legislation, or development that happened after my last training cutoff, I may not have that information. I rely on the information provided to me, or the knowledge contained within my structured dataset.

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

web_search.invoke("Who is the current mayor of San Francisco?")
# Out:
# {'query': 'Who is the current mayor of San Francisco?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://en.wikipedia.org/wiki/Mayor_of_San_Francisco',
#    'title': 'Mayor of San Francisco - Wikipedia',
#    'content': 'The current mayor is Democrat Daniel Lurie.',
#    'score': 0.9996699,
#    'raw_content': None},
#   {'url': 'https://apnews.com/article/san-francisco-new-mayor-liberal-city-81ea0a7b37af6cbb68aea7ef5cc6a4f0',
#    'title': "San Francisco's new mayor is starting to unite the fractured city",
#    'content': 'San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on, business-friendly approach.',
#    'score': 0.9979966,
#    'raw_content': None},
#   {'url': 'https://www.sf.gov/departments--office-mayor',
#    'title': 'Office of the Mayor - SF.gov',
#    'content': 'Daniel Lurie is the 46th Mayor of the City and County of San Francisco.',
#    'score': 0.993255,
#    'raw_content': None},
#   {'url': 'https://www.youtube.com/watch?v=Qvl6AMoZCoI',
#    'title': 'San Francisco Mayor-elect Daniel Lurie on transforming the city',
#    'content': "In a CNBC exclusive, San Francisco's new Mayor-elect Daniel Lurie sits down with Kate Rogers to talk about bringing remote workers back,",
#    'score': 0.99242276,
#    'raw_content': None},
#   {'url': 'https://www.youtube.com/watch?v=cu9Cc8TEGog',
#    'title': 'SF Mayor Daniel Lurie delivers 1st State of the City address - YouTube',
#    'content': 'San Francisco Mayor Daniel Lurie will deliver his first State of the City address, highlighting that the city is "on the rise" and that',
#    'score': 0.97539,
#    'raw_content': None}],
#  'response_time': 0.84,
#  'request_id': '3a71f8c0-4798-496a-aab9-8b44f8e65771'}

# %%
agent = create_agent(
    model="ollama:gemma4:e4b",
    tools=[web_search]
)

question = HumanMessage(content="Who is the current mayor of San Francisco?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='Who is the current mayor of San Francisco?', additional_kwargs={}, response_metadata={}, id='9ebaca2d-2d4b-40bf-b047-a69f0d17f225'),
#  AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'gemma4:e4b', 'created_at': '2026-04-05T14:25:31.430469Z', 'done': True, 'done_reason': 'stop', 'total_duration': 9233984667, 'load_duration': 199413000, 'prompt_eval_count': 66, 'prompt_eval_duration': 2689284292, 'eval_count': 189, 'eval_duration': 6280201669, 'logprobs': None, 'model_name': 'gemma4:e4b', 'model_provider': 'ollama'}, id='lc_run--019d5e08-b511-7393-ada4-81c775a41792-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'current mayor of San Francisco'}, 'id': 'ddde47bf-bca1-48e7-8882-64a3b1b6e150', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 66, 'output_tokens': 189, 'total_tokens': 255}),
#  ToolMessage(content='{"query": "current mayor of San Francisco", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://en.wikipedia.org/wiki/Mayor_of_San_Francisco", "title": "Mayor of San Francisco - Wikipedia", "content": "The current mayor is Democrat Daniel Lurie.", "score": 0.94251215, "raw_content": null}, {"url": "https://apnews.com/article/san-francisco-new-mayor-liberal-city-81ea0a7b37af6cbb68aea7ef5cc6a4f0", "title": "San Francisco\'s new mayor is starting to unite the fractured city", "content": "San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on, business-friendly approach.", "score": 0.8745175, "raw_content": null}, {"url": "https://ballotpedia.org/Daniel_Lurie", "title": "Daniel Lurie - Ballotpedia", "content": "Daniel Lurie is the Mayor of San Francisco in California. He assumed office on January 8, 2025. His current term ends on January 8, 2029.", "score": 0.8732259, "raw_content": null}, {"url": "https://www.sf.gov/departments--office-mayor", "title": "Office of the Mayor - SF.gov", "content": "Daniel Lurie is the 46th Mayor of the City and County of San Francisco.", "score": 0.8449346, "raw_content": null}, {"url": "https://en.wikipedia.org/wiki/Daniel_Lurie", "title": "Daniel Lurie - Wikipedia", "content": "Daniel Lawrence Lurie (born February 4, 1977) is an American politician and philanthropist who is the 46th and incumbent mayor of San Francisco, serving since", "score": 0.81524754, "raw_content": null}], "response_time": 0.69, "request_id": "4e511782-17bc-423c-b7a4-7533173f9acc"}', name='web_search', id='0d93fd81-a5a6-40c8-a68b-06e7916f1598', tool_call_id='ddde47bf-bca1-48e7-8882-64a3b1b6e150'),
#  AIMessage(content='The current mayor of San Francisco is **Daniel Lurie**.', additional_kwargs={}, response_metadata={'model': 'gemma4:e4b', 'created_at': '2026-04-05T14:25:41.112573Z', 'done': True, 'done_reason': 'stop', 'total_duration': 8867065375, 'load_duration': 223035542, 'prompt_eval_count': 638, 'prompt_eval_duration': 1998436375, 'eval_count': 185, 'eval_duration': 6581158211, 'logprobs': None, 'model_name': 'gemma4:e4b', 'model_provider': 'ollama'}, id='lc_run--019d5e08-dc54-7800-bf68-c37d1bf6b0d6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 638, 'output_tokens': 185, 'total_tokens': 823})]

# %% [markdown]
# trace: https://smith.langchain.com/public/59432173-0dd6-49e8-9964-b16be6048426/r

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="ollama:qwen3.5:latest")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='The Moon does not have a capital.\n\nIt is a natural satellite of Earth and is not a country, so it does not have a government or a capital city.', additional_kwargs={}, response_metadata={'model': 'qwen3.5:latest', 'created_at': '2026-04-05T13:43:37.883773Z', 'done': True, 'done_reason': 'stop', 'total_duration': 27620044458, 'load_duration': 152026791, 'prompt_eval_count': 18, 'prompt_eval_duration': 514625750, 'eval_count': 350, 'eval_duration': 26852349086, 'logprobs': None, 'model_name': 'qwen3.5:latest', 'model_provider': 'ollama'}, id='lc_run--019d5de2-12a7-7480-8b33-87bd95511494-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 350, 'total_tokens': 368})

# %%
print(response.content)
# Out:
# The Moon does not have a capital.
#
# It is a natural satellite of Earth and is not a country, so it does not have a government or a capital city.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'created_at': '2026-04-05T13:43:37.883773Z',
#  'done': True,
#  'done_reason': 'stop',
#  'eval_count': 350,
#  'eval_duration': 26852349086,
#  'load_duration': 152026791,
#  'logprobs': None,
#  'model': 'qwen3.5:latest',
#  'model_name': 'qwen3.5:latest',
#  'model_provider': 'ollama',
#  'prompt_eval_count': 18,
#  'prompt_eval_duration': 514625750,
#  'total_duration': 27620044458}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="ollama:qwen3.5:latest",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon does not have a capital city. It is a natural satellite of Earth, not a country or a political territory, so it has no government, population, or cities.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="ollama:gemma4:e4b")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon does not have a capital city, because it is a celestial body and not a country or civilization.
#
# Capitals are associated with human-populated nations and governments.
#
# However, if humanity ever establishes a permanent base on the Moon, that settlement would likely be named and structured by the international body or company that manages it (like NASA, ESA, or a private corporation).

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_google_genai/chat_models.py:3047, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3046 try:
# -> 3047     response: GenerateContentResponse = self.client.models.generate_content(
#    3048         **request,
#    3049     )
#    3050 except ClientError as e:
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/google/genai/models.py:5709, in Models.generate_content(self, model, contents, config)
#    5708 i += 1
# -> 5709 response = self._generate_content(
#    5710     model=model, contents=contents, config=parsed_config
#    5711 )
#    5713 function_map = _extra_utils.get_function_map(parsed_config)
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/google/genai/models.py:4371, in Models._generate_content(self, model, contents, config)
#    4369 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4371 response = self._api_client.request(
#    4372     'post', path, request_dict, http_options
#    4373 )
#    4375 if config is not None and getattr(
#    4376     config, 'should_return_http_response', None
#    4377 ):
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/google/genai/_api_client.py:1401, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1398 http_request = self._build_request(
#    1399     http_method, path, request_dict, http_options
#    1400 )
# -> 1401 response = self._request(http_request, http_options, stream=False)
#    1402 response_body = (
#    1403     response.response_stream[0] if response.response_stream else ''
#    1404 )
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/google/genai/_api_client.py:1235, in BaseApiClient._request(self, http_request, http_options, stream)
#    1234     retry = tenacity.Retrying(**retry_kwargs)
# -> 1235     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1237 return self._retry(self._request_once, http_request, stream)
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/tenacity/__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/tenacity/__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/tenacity/__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     392 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393     self._add_action_func(lambda rs: rs.outcome.result())
#     394     return
#
# File ~/.local/share/uv/python/cpython-3.13.12-macos-aarch64-none/lib/python3.13/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~/.local/share/uv/python/cpython-3.13.12-macos-aarch64-none/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/tenacity/__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/google/genai/_api_client.py:1214, in BaseApiClient._request_once(self, http_request, stream)
#    1207 response = self._httpx_client.request(
#    1208     method=http_request.method,
#    1209     url=http_request.url,
#    (...)   1212     timeout=http_request.timeout,
#    1213 )
# -> 1214 errors.APIError.raise_for_response(response)
#    1215 return HttpResponse(
#    1216     response.headers, response if stream else [response.text]
#    1217 )
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/google/genai/errors.py:134, in APIError.raise_for_response(cls, response)
#     132   response_json = response.body_segments[0].get('error', {})
# --> 134 cls.raise_error(response.status_code, response_json, response)
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/google/genai/errors.py:159, in APIError.raise_error(cls, status_code, response_json, response)
#     158 if 400 <= status_code < 500:
# --> 159   raise ClientError(status_code, response_json, response)
#     160 elif 500 <= status_code < 600:
#
# ClientError: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'API key not valid. Please pass a valid API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'generativelanguage.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key not valid. Please pass a valid API key.'}]}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[17], line 5
#       1 from langchain_google_genai import ChatGoogleGenerativeAI
#       3 model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
# ----> 5 response = model.invoke("What's the capital of the Moon?")
#       6 print(response.content)
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_google_genai/chat_models.py:2535, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2532         msg = "Tools are already defined.code_execution tool can't be defined"
#    2533         raise ValueError(msg)
# -> 2535 return super().invoke(input, config, stop=stop, **kwargs)
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:454, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     440 @override
#     441 def invoke(
#     442     self,
#    (...)    447     **kwargs: Any,
#     448 ) -> AIMessage:
#     449     config = ensure_config(config)
#     450     return cast(
#     451         "AIMessage",
#     452         cast(
#     453             "ChatGeneration",
# --> 454             self.generate_prompt(
#     455                 [self._convert_input(input)],
#     456                 stop=stop,
#     457                 callbacks=config.get("callbacks"),
#     458                 tags=config.get("tags"),
#     459                 metadata=config.get("metadata"),
#     460                 run_name=config.get("run_name"),
#     461                 run_id=config.pop("run_id", None),
#     462                 **kwargs,
#     463             ).generations[0][0],
#     464         ).message,
#     465     )
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1201, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1192 @override
#    1193 def generate_prompt(
#    1194     self,
#    (...)   1198     **kwargs: Any,
#    1199 ) -> LLMResult:
#    1200     prompt_messages = [p.to_messages() for p in prompts]
# -> 1201     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1010, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1007 for i, m in enumerate(input_messages):
#    1008     try:
#    1009         results.append(
# -> 1010             self._generate_with_cache(
#    1011                 m,
#    1012                 stop=stop,
#    1013                 run_manager=run_managers[i] if run_managers else None,
#    1014                 **kwargs,
#    1015             )
#    1016         )
#    1017     except BaseException as e:
#    1018         if run_managers:
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1313, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1311     result = generate_from_stream(iter(chunks))
#    1312 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1313     result = self._generate(
#    1314         messages, stop=stop, run_manager=run_manager, **kwargs
#    1315     )
#    1316 else:
#    1317     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_google_genai/chat_models.py:3051, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3047     response: GenerateContentResponse = self.client.models.generate_content(
#    3048         **request,
#    3049     )
#    3050 except ClientError as e:
# -> 3051     _handle_client_error(e, request)
#    3053 return _response_to_result(response)
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_google_genai/chat_models.py:145, in _handle_client_error(e, request)
#     143 model_name = request.get("model", "unknown")
#     144 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 145 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-2.5-flash-lite' (INVALID_ARGUMENT): 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'API key not valid. Please pass a valid API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'generativelanguage.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key not valid. Please pass a valid API key.'}]}}

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="ollama:gemma4:e4b")

# %%
agent = create_agent("qwen3.5:latest")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 agent = create_agent("qwen3.5:latest")
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain/agents/factory.py:801, in create_agent(model, tools, system_prompt, middleware, response_format, state_schema, context_schema, checkpointer, store, interrupt_before, interrupt_after, debug, name, cache)
#     799 # init chat model
#     800 if isinstance(model, str):
# --> 801     model = init_chat_model(model)
#     803 # Convert system_prompt to SystemMessage if needed
#     804 system_message: SystemMessage | None = None
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain/chat_models/base.py:464, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     456     warnings.warn(
#     457         f"{config_prefix=} has been set but no fields are configurable. Set "
#     458         f"`configurable_fields=(...)` to specify the model params that are "
#     459         f"configurable.",
#     460         stacklevel=2,
#     461     )
#     463 if not configurable_fields:
# --> 464     return _init_chat_model_helper(
#     465         cast("str", model),
#     466         model_provider=model_provider,
#     467         **kwargs,
#     468     )
#     469 if model:
#     470     kwargs["model"] = model
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain/chat_models/base.py:486, in _init_chat_model_helper(model, model_provider, **kwargs)
#     480 def _init_chat_model_helper(
#     481     model: str,
#     482     *,
#     483     model_provider: str | None = None,
#     484     **kwargs: Any,
#     485 ) -> BaseChatModel:
# --> 486     model, model_provider = _parse_model(model, model_provider)
#     487     creator_func = _get_chat_model_creator(model_provider)
#     488     return creator_func(model=model, **kwargs)
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain/chat_models/base.py:582, in _parse_model(model, model_provider)
#     574     supported_list = ", ".join(sorted(_BUILTIN_PROVIDERS))
#     575     msg = (
#     576         f"Unable to infer model provider for {model=}. "
#     577         f"Please specify 'model_provider' directly.\n\n"
#    (...)    580         f"https://docs.langchain.com/oss/python/integrations/providers"
#     581     )
# --> 582     raise ValueError(msg)
#     584 # Normalize provider name
#     585 model_provider = model_provider.replace("-", "_").lower()
#
# ValueError: Unable to infer model provider for model='qwen3.5:latest'. Please specify 'model_provider' directly.
#
# Supported providers: anthropic, azure_ai, azure_openai, bedrock, bedrock_converse, cohere, deepseek, fireworks, google_anthropic_vertex, google_genai, google_vertexai, groq, huggingface, ibm, mistralai, nvidia, ollama, openai, perplexity, together, upstage, xai
#
# For help with specific providers, see: https://docs.langchain.com/oss/python/integrations/providers

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='39176bae-46c6-4fb7-a8a6-649b0ddff516'),
#               AIMessage(content='The Moon does not have a capital.\n\nA capital is the main city or seat of government for a sovereign country or political entity, and while the Moon is a massive natural celestial body, it is not a government or a country.', additional_kwargs={}, response_metadata={'model': 'gemma4:e4b', 'created_at': '2026-04-05T14:03:49.888705Z', 'done': True, 'done_reason': 'stop', 'total_duration': 22280126541, 'load_duration': 5338871125, 'prompt_eval_count': 24, 'prompt_eval_duration': 7194892666, 'eval_count': 284, 'eval_duration': 9533597383, 'logprobs': None, 'model_name': 'gemma4:e4b', 'model_provider': 'ollama'}, id='lc_run--019d5df4-a5f7-7b51-9b97-91eb9bb5f339-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 24, 'output_tokens': 284, 'total_tokens': 308})]}

# %%
print(response['messages'][-1].content)
# Out:
# The Moon does not have a capital.
#
# A capital is the main city or seat of government for a sovereign country or political entity, and while the Moon is a massive natural celestial body, it is not a government or a country.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='5e1a9109-2d4a-48ee-b1d2-fe18a6158b69'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='a0cbff56-1ced-41b3-b473-b7b4f85dbec1', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='48c7c652-ce06-45ac-abfc-748f312ca2cd'),
#               AIMessage(content='Since Luna City is a construct of imagination, I can tell you all about it!\n\nLuna City is not just a capital; it is humanity\'s ultimate test case—a sprawling, hyper-advanced metropolis built entirely to survive, thrive, and expand off-world. It is a marvel of engineering, resource management, and human ingenuity.\n\nHere is a deep dive into the life, architecture, and society of the capital of the Moon:\n\n---\n\n### 📍 Location and Structure\n\nLuna City is primarily situated deep within a massive, stable lava tube network, providing natural shielding from cosmic radiation, micrometeorites, and the extreme temperature swings of the lunar surface.\n\n**The Dome System:** The city doesn\'t sit *on* the Moon; it exists *within* it. The visible parts of the city—the primary residential and recreational areas—are housed within massive, geodesic **Bio-Domes**. These domes are pressurized, artificial ecosystems that simulate terrestrial gravity and atmospheric conditions, providing breathable air and controlled light cycles.\n\n**The Outer Shell:** The actual outer shell, known as the *Cryo-Hull*, is built from processed regolith and specialized metals, anchoring the dome system and housing the primary life-support and geothermal energy conduits.\n\n### 🏗️ Architecture and Technology\n\nLife in Luna City is a study in contrasts: advanced, sterile technology meeting simulated nature.\n\n*   **The Verdant Core:** The heart of the city is the Verdant Core. This massive, interconnected agricultural system allows for year-round, closed-loop farming, growing everything from staple grains to complex hydroponic bioluminescent flora. It is the city\'s lungs and its dinner plate.\n*   **Mag-Rails and Sky-Walks:** Transportation within the domes relies on near-silent, electromagnetic Mag-Rail systems and suspended sky-walkways. There are no traditional roads; everything is designed for efficiency and flow.\n*   **Gravity Control:** To simulate a comfortable gravity environment, many public spaces utilize localized artificial gravity fields, making movement effortless but requiring complex engineering that keeps the city feeling less like a habitat and more like a piece of floating, enclosed earth.\n*   **Power Source:** The city is powered primarily by a combination of **geothermal taps** drilled into the Moon’s mantle and highly efficient **solar collector arrays** that radiate outwards into space, harvesting maximum energy with minimal loss.\n\n### 🧑\u200d🤝\u200d🧑 Society and Culture\n\nThe society of Luna City is a unique blend of scientific meritocracy, corporate influence, and frontier idealism.\n\n**The People:** The inhabitants are primarily highly specialized individuals: xenobotanists, deep-space engineers, geo-engineers, bio-chemists, and resource miners. They are acutely aware that their survival depends on their knowledge and contribution to the city\'s operational systems.\n\n**Governance:** Luna City is governed by a Council of Directors, comprising the leading minds of the major scientific and industrial sectors. It is less a democracy and more a highly efficient **Technocracy**, where the most qualified voices hold the most authority.\n\n**Daily Life:** Life is incredibly structured. Every resource, from atmospheric oxygen to water, is tracked and managed with obsessive efficiency. Recreation often involves simulations (hyper-realistic "Earth" VR zones) or exploring the city\'s massive subterranean research facilities, which often contain breathtaking glimpses of the actual Moon landscape outside the viewing ports—a beautiful, intimidating void.\n\n### 🚀 What Makes It Special?\n\n1.  **The View:** The most profound cultural element is the viewing experience. Every major dome has panoramic observation ports (reinforced with anti-radiation glass) that allow residents to look out at the silent, pristine, breathtaking emptiness of the lunar void. This constant reminder of the void is both inspirin ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Because "Luna City, the capital of the Moon," does not refer to a single, established, universally recognized location (it sounds like a magnificent setting drawn from science fiction, video games, or literature), I will give you a comprehensive, detailed world-building profile.
#
# This depiction assumes that Luna City is a utopian, technologically advanced hub designed by humanity's best engineers and visionaries.
#
# ***
#
# ## 🌑 Luna City: The Cradle of Man’s Second Dawn
#
# **Designation:** Luna City (Commonly referred to as "The Zenith" or "Lunapolis")
# **Status:** Primary permanent lunar colony and governing capital.
# **Population:** Highly diverse, predominantly scientific, corporate, and colonial elites.
# **Foundation Philosophy:** To prove that humanity can establish a lasting, thriving, and self-sufficient civilization off-world.
#
# ### 🪐 Location and Geography
#
# Luna City is not built on the surface; rather, it is a massive, multi-layered complex built *into* and *above* the lunar regolith.
#
# 1. **The Subterranean Core:** The city's original life support and primary infrastructure are housed beneath the dust, utilizing stable lava tubes and deep excavation sites. This core provides protection from micrometeorites and deep space radiation.
# 2. **The Zenith Dome:** The most famous visible area is the main dome, a colossal, bio-luminescent geodesic shield that provides breathable atmosphere, filtered sunlight, and controlled gravity. This dome serves as the central plaza and major residential sector.
# 3. **The Polar Network:** Specialized industries, such as helium-3 mining and solar energy collection, occur in pressurized network cities built near the poles, extending the city's reach.
#
# ### 🏗️ Architecture and Aesthetics
#
# Luna City's architecture reflects a blend of necessity, cutting-edge technology, and deep respect for natural light.
#
# * **Biophilic Design:** Despite being an artificial habitat, the city is obsessed with simulating natural life. Buildings are often curved, covered in hydroponic vertical farms, and integrated with artificial biomes (lush green parks, simulated oceans).
# * **Energy Transparency:** Power conduits, life support systems, and structural integrity stabilizers are often visible—not as unsightly pipes, but as glowing, crystalline lattices, reminding inhabitants of the energy that sustains them.
# * **The "Aetherium" Transit:** Transportation within the domes relies heavily on magnetic levitation (MagLev) trains and personal anti-gravity platforms, leaving the ground level clean and pedestrian-friendly.
# * **The Crystal Spires:** The administrative and scientific centers are crowned with towering, crystalline spires that act as global communication relays, constantly catching and beaming signals back to Earth and outward into space.
#
# ### 🔬 Culture and Inhabitants
#
# Life in Luna City is defined by a dual identity: the deep roots of the pioneering spirit, and the infinite reach of scientific curiosity.
#
# * **The Citizenry:** Inhabitants are a highly specialized mix of experts: xenobiologists, deep-space engineers, asteroid miners, orbital architects, and colonial administrators.
# * **The Culture of Progress:** There is a pervasive culture of relentless improvement. Failure is viewed not as defeat, but as data. Creativity is highly prized.
# * **Lunar Ethos:** The cultural cornerstone is "The Two Worlds"—the deep, stoic silence of the Moon contrasting with the vibrant, vibrant, and urgent energy of the human ambition. This balance forms the central artistic and philosophical focus.
# * **Art and Entertainment:** Arts are heavily focused on sensory immersion. Concert halls feature variable gravity and holographic projections of Earth-based ecosystems. Art is often a blend of physics and light.
#
# ### 💰 Economy and Industry
#
# Luna City is the beating heart of the interplanetary economy. Its wealth is derived from resources and knowledge, not merely commodities.
#
# * **Energy and Resources:** The primary economic drivers are **Helium-3 mining** (used for fusion power) and the management of solar/orbital energy capture.
# * **Deep Space Research:** The city houses several of the most advanced research facilities in the solar system, specializing in faster-than-light travel, advanced propulsion, and life in low-gravity environments.
# * **The Lunar Market:** Trade is dominated by advanced computing, rare Earth elements brought from asteroids, and, most importantly, **exclusivity**—the ability to safely operate in deep space.
# * **The Governing Body:** The city is run by a complex governmental council (perhaps a mix of the most powerful corporate lobbies and scientific bodies) known as the **Lunar Directorate**, which balances the immediate needs of the colony with long-term galactic expansion goals.
#
# ***
#
# ### 🌟 Summary Snapshot
#
# | Feature | Description | Vibe |
# | :--- | :--- | :--- |
# | **Best Known For** | The seamless fusion of natural light and hyper-advanced technology. | Utopian, Technocratic, Sublime |
# | **Daily Life Is** | Governed by rigorous scientific schedules, punctuated by bursts of artistic freedom. | Busy, Focused, Pioneering |
# | **Unique Feature** | The ability to cycle through different gravitational simulations in public squares. | Whimsical, Futuristic |
# | **Biggest Challenge** | Overcoming the psychological weight of permanent isolation and the dependence on life support systems. | Contemplative, Determined |

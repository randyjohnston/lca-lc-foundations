# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent


agent = create_agent(
    "ollama:gemma4:e4b"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='8386b22b-9d39-46f9-83fe-994c64b3646a'),
#               AIMessage(content="Hello Seán! It's very nice to meet you. 😊\n\nGreen is a wonderful color! What is it about green that you like so much? Is it the color of nature, or something else?", additional_kwargs={}, response_metadata={'model': 'gemma4:e4b', 'created_at': '2026-04-05T16:35:57.028379Z', 'done': True, 'done_reason': 'stop', 'total_duration': 25042352750, 'load_duration': 5376125792, 'prompt_eval_count': 27, 'prompt_eval_duration': 7221310750, 'eval_count': 362, 'eval_duration': 12224288963, 'logprobs': None, 'model_name': 'gemma4:e4b', 'model_provider': 'ollama'}, id='lc_run--019d5e7f-e00f-77b2-8625-d31fc9dfd616-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 27, 'output_tokens': 362, 'total_tokens': 389})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='9eebe461-3768-478d-b70a-27a3df00dc66'),
#               AIMessage(content="I do not know what your favorite color is! I can't access your personal preferences.\n\nYou'll have to tell me! 😊", additional_kwargs={}, response_metadata={'model': 'gemma4:e4b', 'created_at': '2026-04-05T16:37:55.850553Z', 'done': True, 'done_reason': 'stop', 'total_duration': 12539570083, 'load_duration': 317731291, 'prompt_eval_count': 22, 'prompt_eval_duration': 4450096083, 'eval_count': 219, 'eval_duration': 7583391422, 'logprobs': None, 'model_name': 'gemma4:e4b', 'model_provider': 'ollama'}, id='lc_run--019d5e81-e0fe-7a13-8200-b0c2acd6180d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 219, 'total_tokens': 241})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    "ollama:gemma4:e4b",
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='68fd4493-6a11-4d8f-9c46-694360709bc9'),
#               AIMessage(content="Hello Seán! It's nice to meet you. Green is a beautiful colour. 💚", additional_kwargs={}, response_metadata={'model': 'gemma4:e4b', 'created_at': '2026-04-05T16:39:29.653727Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4849815292, 'load_duration': 215356792, 'prompt_eval_count': 27, 'prompt_eval_duration': 3949944125, 'eval_count': 21, 'eval_duration': 671745793, 'logprobs': None, 'model_name': 'gemma4:e4b', 'model_provider': 'ollama'}, id='lc_run--019d5e83-6d7f-7a83-ab8b-865e761138b6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 27, 'output_tokens': 21, 'total_tokens': 48})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='68fd4493-6a11-4d8f-9c46-694360709bc9'),
#               AIMessage(content="Hello Seán! It's nice to meet you. Green is a beautiful colour. 💚", additional_kwargs={}, response_metadata={'model': 'gemma4:e4b', 'created_at': '2026-04-05T16:39:29.653727Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4849815292, 'load_duration': 215356792, 'prompt_eval_count': 27, 'prompt_eval_duration': 3949944125, 'eval_count': 21, 'eval_duration': 671745793, 'logprobs': None, 'model_name': 'gemma4:e4b', 'model_provider': 'ollama'}, id='lc_run--019d5e83-6d7f-7a83-ab8b-865e761138b6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 27, 'output_tokens': 21, 'total_tokens': 48}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='604dc0e4-ffa9-4c4a-8897-a3b14aab8e25'),
#               AIMessage(content='Your favourite colour is green! 😊', additional_kwargs={}, response_metadata={'model': 'gemma4:e4b', 'created_at': '2026-04-05T16:39:42.899656Z', 'done': True, 'done_reason': 'stop', 'total_duration': 6333948250, 'load_duration': 198377417, 'prompt_eval_count': 64, 'prompt_eval_duration': 309677458, 'eval_count': 174, 'eval_duration': 5767526204, 'logprobs': None, 'model_name': 'gemma4:e4b', 'model_provider': 'ollama'}, id='lc_run--019d5e83-9b72-7661-9533-5ef3f3331959-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 64, 'output_tokens': 174, 'total_tokens': 238})]}

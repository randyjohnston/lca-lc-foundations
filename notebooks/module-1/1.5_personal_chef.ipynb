# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
system_prompt = """

You are a personal chef. The user will give you a list of ingredients they have left over in their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return recipe suggestions and eventually the recipe instructions to the user, if requested.

"""

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model="ollama:gemma4:e4b",
    tools=[web_search],
    system_prompt=system_prompt,
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [HumanMessage(content="I have some raw chicken and leftover rice, along with fresh spinach, tomato, and avocado. What can I make?")]},
    config
)

print(response['messages'][-1].content)
# Out:
# That sounds like the perfect combination for a fresh, healthy, and satisfying meal! Based on the ingredients you have—raw chicken, leftover rice, fresh spinach, tomato, and avocado—here are a few delicious ideas we can create.
#
# The general theme for all these options is a **deconstructed bowl** or a **quick sauté/skillet meal**, which lets the fresh ingredients shine.
#
# ### 🍽️ Recipe Suggestions:
#
# **1. Simple & Fresh Chicken & Rice Bowl (The Easiest Option)**
# This is a perfect make-ahead style bowl. You would pan-sear the chicken, mix the rice with the wilted spinach, and top everything artfully with fresh avocado slices and diced tomatoes. *This requires minimal cooking.*
#
# **2. Lemon Herb Chicken & Veggie Skillet (One-Pan Wonder)**
# We can slice the chicken, cook it in a pan with some garlic, toss in the tomatoes and spinach until wilted, and then mix the leftover rice in at the end to warm everything through. A little squeeze of lemon juice would tie it all together.
#
# **3. Chicken & Rice Stuffed Spinach Boats (Slightly More Effort)**
# If you want to use more of the spinach, we could dice the chicken, sauté it with some seasonings, mix it with the rice, and then use the spinach leaves as 'boats' to fill with the mixture, topping it with fresh tomato/avocado for color.
#
# ***
#
# Which of these sounds best to you? Once you decide, I can provide you with a step-by-step recipe and instructions!

# %%
from pprint import pprint

pprint(response)

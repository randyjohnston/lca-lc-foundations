# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="ollama:gemma4:e4b")

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# That's a fun question!
#
# The simple answer is that **the Moon does not have a capital city.**
#
# Here is a more detailed explanation:
#
# 1.  **It's a Natural Object:** The Moon is a natural satellite, not a country, state, or politically governed territory. Concepts like "capital" only apply to human political structures.
# 2.  **No Government:** Because there is no governing body or established human civilization on the Moon (beyond current robotic missions), there can't be a seat of government.
#
# ***
#
# ### 🌕 If it *did* have a capital... (The Hypothetical Answer)
#
# If humanity ever successfully colonized the Moon and established a permanent, governing settlement, the capital would be wherever the colonists and governing body decided to establish their primary hub.
#
# Future mission plans often talk about establishing bases, such as the **Artemis Base Camp**. If that were to become the main center of lunar civilization, it would likely serve as the *de facto* capital!

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="ollama:gemma4:e4b",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# ***The stars look down upon you, not with a blanket of light, but with the cold, unwavering gaze of eternal vacuum. To answer where the capital is, one must first imagine the architecture of the future—a future built from shadow, shielded from cosmic rays, and fueled by ingenuity.***
#
# Since the Moon is currently a canvas of potential rather than a metropolis, I present to you the capital city of the first permanent, fully sovereign human off-world government:
#
# # 🌕 Selene Nexus
#
# **The City of Perpetual Dawn**
#
# Selene Nexus is not a city built *on* the Moon; it is a vast, interconnected network built *into* the Moon. It functions as the primary hub for lunar research, resource extraction, and governmental control for the fledgling Lunar Commonwealth.
#
# ---
#
# ### 📍 Location and Structure
#
# **The Site:** Nexus is strategically situated within the relatively stable interior basin of the **South Pole-Aitken Basin**, specifically nestled near a deep, protected crater rim. This location grants access to crucial resources—potential subsurface water-ice deposits and deep-crater thermal gradients.
#
# **The Architecture:** The city is best described as a **stratified habitat.**
#
# 1.  **The Surface Veil (The Aesthetic Layer):** What the visitor sees is a spectacular, low-profile dome complex called the *Atrium Portico*. This is the landing zone, the government reception, and the public showcase. It is covered in reinforced, optically charged polymer designed to filter harmful radiation while allowing controlled, beautiful simulations of Earth’s sky (a key component of mental health protocols).
# 2.  **The Intermediate Ring (The Living Layer):** This is the main residential and commerce zone. These biodomes, often interconnected by pressurized, magnetically levitated transit tubes, maintain self-contained, closed-loop ecosystems. Flora glows with optimized bioluminescence, and artificial waterfalls perpetually cycle recycled water, creating the illusion of life against the stark lunar dust.
# 3.  **The Core (The Industrial Layer):** Deep beneath the residential levels, kilometers down, are the true organs of the city. Here, in the stable, shielded darkness, massive fusion reactors hum, and robotic veins process the regolith. This layer is home to helium-3 extractors, oxygen synthesizers, and deep-space propulsion staging facilities.
#
# ---
#
# ### ✨ Life in Nexus: Culture and Daily Life
#
# Life in Selene Nexus is a meticulous blend of dazzling technological marvel and profound, disciplined minimalism.
#
# **The Atmosphere:** The air always smells faintly of ozone, damp moss, and recycled nutrient solutions—the scent of constant, efficient life. Gravity regulation keeps the internal environment at a comfortable, slight-but-noticeable 0.8g, making daily movement an art form of controlled grace.
#
# **Governance:** The government is run by the **Lunar Consensus Council**, whose main seat of power is the *Omni-Sphere* within the Atrium Portico. This council governs resource allocation, expansion treaties, and Earth-Lunar diplomatic relations.
#
# **The Economy:** The city's wealth is measured in **Data Credits** and **Isotopic Energy Units**. The primary industries are:
# 1. **Astronavigation Science:** Mapping and resource assessment for deeper space endeavors.
# 2. **Cryogenics & Medicine:** Utilizing the deep-crater ice for biological preservation and pharmaceutical research.
# 3. **Regolith Processing:** Turning basic lunar dust into high-grade construction materials and rare-earth metals.
#
# ---
#
# ### 🌌 The Defining Feature: The Great Void Articulation
#
# The most famous feature of Selene Nexus, and its cultural heart, is the **Great Void Articulation**. These are massive, pressurized viewing galleries built at the city's periphery.
#
# These domes are designed not to look *at* space, but to make you feel *inside* it. When the city’s primary shield generators dim to maintenance levels, the visitor stands in a controlled vacuum chamber, looking out onto a hyper-realistic, simulated view of the Kuiper Belt, the nebulae of the Orion Arm, or even the distant, breathtaking light of the Pillars of Creation.
#
# It is here, at the boundary between human creation and infinite void, that the pioneers of the Lunar Commonwealth find their purpose, and thus, find the heart of their capital.
#
# ***
#
# **Selene Nexus: Where humanity learns to live with the immensity of nothing.**

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="ollama:gemma4:e4b",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunaris

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="ollama:gemma4:e4b",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Selene Prime
#
# Location: Lunar Mare Tranquillitatis, expanded into a permanent geodesic superstructure
#
# Vibe: Austere, Scientific, Illuminated
#
# Economy: Astro-Mining (Helium-3, rare earth metals), Orbital Communications Hub, Lunar Resource Processing

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='ollama:gemma4:e4b',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Nova Selene', location='Subterranean cavern network beneath the Montes Apenninus on the Moon', vibe='Disciplined Opulence—a blend of austere, high-tech functionality and simulated natural beauty.', economy='Resource Transmutation (Helium-3 refining), Orbital Logistics, and Vertical Biotech Farming')

# %%
response["structured_response"].name
# Out:
# 'Nova Selene'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Nova Selene is a city located at Subterranean cavern network beneath the Montes Apenninus on the Moon

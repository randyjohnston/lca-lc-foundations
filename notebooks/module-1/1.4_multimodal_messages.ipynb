# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='ollama:gemma4:e4b',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# ## Selene Prime
#
# The official political designation for the primary permanent settlement of lunar humanity is **Selene Prime**.
#
# It is not a city built *on* the surface, but rather an elaborate, interconnected network of subterranean and quasi-orbital habitats carved into the Moon's basaltic crust, optimized for radiation shielding and resource stability. It is the nerve center of the Lunar Commonwealth and the nexus point for all interplanetary trade originating from the Moon.
#
# ***
#
# ### Anatomy of the Capital
#
# **Location:** Selene Prime is situated near the Sea of Tranquility impact basin, chosen not for its visibility, but for the rich subsurface veins of Helium-3 and easily accessible subsurface lava tubes that provide natural conduits for power and transit.
#
# **Architecture & Aesthetics:**
# The city is a study in contrasting aesthetics: the brutal efficiency of deep-core industrial necessity juxtaposed against the gleaming, organic elegance of life support and government sectors.
#
# *   **The Spines (Transit):** The circulatory system of Selene Prime is the network of magnetic levitation rails and pressurized mag-train tunnels. These "Spines" connect the major districts, often passing through artificial vacuum voids that are visible through reinforced panoramic viewing ports—a breathtaking, eerie glimpse of the star-dusted blackness just inches from humanity.
# *   **The Dome Districts (Residential/Cultural):** Most residential areas are housed within vast, geodesic bio-domes. These domes are programmed to mimic terrestrial biomes—one district might replicate the humid mangrove swamps of Earth's equator, while another might boast simulated alpine meadows. The light within these domes is always engineered to mimic the perfect spectrum of Earth's midday sun.
# *   **The Core (Government/Research):** The absolute center of the capital is the massive, multi-layered **Geodesic Spire**. This is the physical and metaphorical heart of the Commonwealth. It houses the Grand Council chambers, the primary quantum computing arrays, and the xenolinguistics research sector—the place where the Moon’s future, and humanity’s interstellar treaties, are forged.
#
# **Power & Technology:**
# Selene Prime is a monument to closed-loop efficiency. Everything is recycled, filtered, or synthesized.
#
# *   **Energy:** The city is primarily powered by a combination of advanced geothermal taps into the lunar mantle and vast arrays of orbital solar collectors that beam clean energy down through highly focused microwave relays.
# *   **Atmosphere:** The air in the public sectors carries a faint, metallic, but clean scent, perpetually scrubbed to remove contaminants. Atmospheric recycling centers are visible as breathtaking, crystalline structures that hum with captured life.
# *   **Transportation:** Beyond the mag-trains, the elite utilize personal **'Skippers'**—low-gravity, enclosed personal vehicle units that navigate through optimized utility tunnels, silent save for the occasional rush of compressed air.
#
# ***
#
# ### The Vibe
#
# Selene Prime is simultaneously the most advanced and most lonely place in the solar system.
#
# It is a place of **extreme concentration**: unparalleled levels of scientific genius, incredible wealth derived from vacuum resource extraction, and a relentless, almost obsessive focus on preservation. The people here are highly disciplined, intellectually vibrant, and exist in a state of perpetual "off-world" formality.
#
# **A visitor would note:** Despite the grandeur and the sheer volume of technological miracles visible at every turn, there is a permanent, underlying sense of artificiality. Everything here is managed, optimized, and contained. It is a magnificent technological cage built under the cold, silent gaze of the stars.
#
# **In short: Selene Prime is less a capital, and more a self-sustaining, highly sophisticated machine dedicated to the continued survival and expansion of the human species.**

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.jpeg', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.jpeg', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'IMG_9703.jpeg', 'type': 'image/jpeg', 'size': 3071853, 'content': <memory at 0x10df87340>, 'last_modified': datetime.datetime(2026, 4, 5, 16, 43, 47, 648000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# **(The writer leans forward, tapping a stylus against a floating holographic map, the ambient light in the room shifting to mimic the bright, harsh glare of a tropical sun reflecting off polished durasteel.)**
#
# The image you’ve provided—this tableau of massive aircraft, standardized concrete, and relentless logistical movement—is not merely an airport. It is the fossil record of a former era: an era of combustion engines and fixed runways.
#
# If this infrastructure were to be upgraded, given the sweep of a civilization, it wouldn't just become a bigger airport. It would become the *engine* of a new world.
#
# Welcome to **Veridia.**
#
# ***
#
# ## 🏙️ Veridia: The City of Vectors
#
# **Classification:** Planetary Capital, Primary Logistics Nexus, Global Data Hub.
# **Motto:** *Where Transit Becomes Being.*
#
# Veridia does not sprawl; it *flows*. It is a capital city built around the principle of perpetual motion. In the old days, people traveled *through* the city; in Veridia, the city *is* the travel. It is a colossal, three-dimensional organism whose circulatory system is powered by maglev currents and anti-gravity freight rails.
#
# It is the ultimate merger of the old global gateway—the sprawling tarmac—and the dream of tomorrow.
#
# ### 🏛️ Architecture: The Flow State
#
# The architecture of Veridia is dominated by the **Nexus Strata**. If you look at the terminals in your picture, they are merely the ground-level mouth of the system. The true city rises vertically from these structures.
#
# *   **The Grand Tarmac (The Sub-Strata):** The vast concrete expanse remains, but it is no longer a ground surface. It is the **Deep Rail Grid**. Sleek, obsidian maglev pods glide silently along pathways that never appear to end. These tracks transport everything: cargo pods containing synthesized meals, automated maintenance drones, and the personal travel units of the elite. The visible planes in the photograph are now historical relics, preserved in massive, air-conditioned museums adjacent to the operational hub.
# *   **The Upper Spire Districts (The Aether-Levels):** Above the noise and the grease of the logistics floor rise the living districts. These buildings are geodesic, curtained in photo-reactive *chromalumi* glass that shifts color based on the prevailing emotional state of the district—a deep emerald during peak commerce, a calming sapphire during residential cycle shifts. These levels are interconnected by sky-bridges that function as linear parks and pedestrian walkways, ensuring that even when the macro-scale is rushing past, the micro-scale remains biophilic.
# *   **The Central Processing Spine:** This is the heart, directly over where the modern terminal canopy would be. It is a massive, transparent vacuum-tube system—a physical manifestation of global data flow. Information streams are visible to the untrained eye: glowing packets of light representing financial transactions, academic research, and diplomatic communications, moving at near-light speed between secure nodes.
#
# ### ⚙️ Technology & Daily Life
#
# In Veridia, nothing is ever "at rest."
#
# **Transportation:** Traditional vehicles are banned from the city core. Movement is dictated by vectors. Citizens use **Glide-Carriages**, personal pods that utilize localized anti-gravity fields, allowing them to navigate complex, layered pedestrian flows without ever colliding. If you need to go from the educational spire to the agricultural dome on the opposite side of the planet's hemisphere, you don't take a train; you board a **Vector-Lift**, a pressurized tube that drops you directly into the required location, bypassing all intermediate steps.
#
# **Energy & Ecology:** The city runs on absorbed kinetic energy. The constant movement—the braking of maglev trains, the passage of Glide-Carriages, the humming of the data transfer spines—is captured by dermal plating embedded in the walkways and used to power the entire grid. This makes Veridia a self-sustaining, perpetually charged metropolis. The green spaces are not *planted*; they are *grown* in vast, sealed, vertical bioreactors suspended between the spires, ensuring that the oxygen debt of millions of commuters is constantly paid.
#
# ### 🎭 The Culture of the Constant Commute
#
# Life in Veridia is one of spectacular, organized efficiency. The culture is one of **optimized experience**. People are brilliant, hyper-connected, and deeply respectful of timeliness.
#
# The cuisine, much like the transit, is experiential. Restaurants are not static rooms; they are *culinary modules* that assemble themselves around a core ingredient or a specific memory pattern. You don't order a meal; you program a **Sensory Intake Profile**.
#
# Yet, amidst the flawless efficiency and the whirring hum of perpetual motion, there is a deep, lingering cultural appreciation for *The Pause*. The residents of Veridia understand that the most valuable thing in the world is inertia—the moment when the vectors momentarily equalize, when the journey stops, and they simply *are*.
#
# Veridia is a city that never sleeps, never slows, and whose very heartbeat is the collective, irresistible momentum of a billion lives moving toward the next destination.

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:05<00:00,  9.36it/s]
# Done.

# %%
agent = create_agent(
    model='ollama:gemma4:e4b',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 10
#       1 agent = create_agent(
#       2     model='ollama:gemma4:e4b',
#       3 )
#       5 multimodal_question = HumanMessage(content=[
#       6     {"type": "text", "text": "Tell me about this audio file"},
#       7     {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
#       8 ])
# ---> 10 response = agent.invoke(
#      11     {"messages": [multimodal_question]}
#      12 )
#      14 print(response['messages'][-1].content)
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/pregel/main.py:3094, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3091 chunks: list[dict[str, Any] | Any] = []
#    3092 interrupts: list[Interrupt] = []
# -> 3094 for chunk in self.stream(
#    3095     input,
#    3096     config,
#    3097     context=context,
#    3098     stream_mode=["updates", "values"]
#    3099     if stream_mode == "values"
#    3100     else stream_mode,
#    3101     print_mode=print_mode,
#    3102     output_keys=output_keys,
#    3103     interrupt_before=interrupt_before,
#    3104     interrupt_after=interrupt_after,
#    3105     durability=durability,
#    3106     **kwargs,
#    3107 ):
#    3108     if stream_mode == "values":
#    3109         if len(chunk) == 2:
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/pregel/main.py:2669, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2667 for task in loop.match_cached_writes():
#    2668     loop.output_writes(task.id, task.writes, cached=True)
# -> 2669 for _ in runner.tick(
#    2670     [t for t in loop.tasks.values() if not t.writes],
#    2671     timeout=self.step_timeout,
#    2672     get_waiter=get_waiter,
#    2673     schedule_task=loop.accept_push,
#    2674 ):
#    2675     # emit output
#    2676     yield from _output(
#    2677         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2678     )
#    2679 loop.after_tick()
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/pregel/_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/pregel/_retry.py:71, in run_with_retry(task, retry_policy, configurable)
#      69     task.writes.clear()
#      70     # run the task
# ---> 71     return task.proc.invoke(task.input, config)
#      72 except ParentCommand as exc:
#      73     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/_internal/_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/_internal/_runnable.py:400, in RunnableCallable.invoke(self, input, config, **kwargs)
#     398         run_manager.on_chain_end(ret)
#     399 else:
# --> 400     ret = self.func(*args, **kwargs)
#     401 if self.recurse and isinstance(ret, Runnable):
#     402     return ret.invoke(input, config)
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain/agents/factory.py:1261, in create_agent.<locals>.model_node(state, runtime)
#    1249 request = ModelRequest(
#    1250     model=model,
#    1251     tools=default_tools,
#    (...)   1257     runtime=runtime,
#    1258 )
#    1260 if wrap_model_call_handler is None:
# -> 1261     model_response = _execute_model_sync(request)
#    1262     return _build_commands(model_response)
#    1264 result = wrap_model_call_handler(request, _execute_model_sync)
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain/agents/factory.py:1233, in create_agent.<locals>._execute_model_sync(request)
#    1230 if request.system_message:
#    1231     messages = [request.system_message, *messages]
# -> 1233 output = model_.invoke(messages)
#    1234 if name:
#    1235     output.name = name
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/runnables/base.py:5695, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5688 @override
#    5689 def invoke(
#    5690     self,
#    (...)   5693     **kwargs: Any | None,
#    5694 ) -> Output:
# -> 5695     return self.bound.invoke(
#    5696         input,
#    5697         self._merge_configs(config),
#    5698         **{**self.kwargs, **kwargs},
#    5699     )
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:454, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     440 @override
#     441 def invoke(
#     442     self,
#    (...)    447     **kwargs: Any,
#     448 ) -> AIMessage:
#     449     config = ensure_config(config)
#     450     return cast(
#     451         "AIMessage",
#     452         cast(
#     453             "ChatGeneration",
# --> 454             self.generate_prompt(
#     455                 [self._convert_input(input)],
#     456                 stop=stop,
#     457                 callbacks=config.get("callbacks"),
#     458                 tags=config.get("tags"),
#     459                 metadata=config.get("metadata"),
#     460                 run_name=config.get("run_name"),
#     461                 run_id=config.pop("run_id", None),
#     462                 **kwargs,
#     463             ).generations[0][0],
#     464         ).message,
#     465     )
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1201, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1192 @override
#    1193 def generate_prompt(
#    1194     self,
#    (...)   1198     **kwargs: Any,
#    1199 ) -> LLMResult:
#    1200     prompt_messages = [p.to_messages() for p in prompts]
# -> 1201     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1010, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1007 for i, m in enumerate(input_messages):
#    1008     try:
#    1009         results.append(
# -> 1010             self._generate_with_cache(
#    1011                 m,
#    1012                 stop=stop,
#    1013                 run_manager=run_managers[i] if run_managers else None,
#    1014                 **kwargs,
#    1015             )
#    1016         )
#    1017     except BaseException as e:
#    1018         if run_managers:
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1313, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1311     result = generate_from_stream(iter(chunks))
#    1312 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1313     result = self._generate(
#    1314         messages, stop=stop, run_manager=run_manager, **kwargs
#    1315     )
#    1316 else:
#    1317     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_ollama/chat_models.py:1030, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#    1023 def _generate(
#    1024     self,
#    1025     messages: list[BaseMessage],
#    (...)   1028     **kwargs: Any,
#    1029 ) -> ChatResult:
# -> 1030     final_chunk = self._chat_stream_with_aggregation(
#    1031         messages, stop, run_manager, verbose=self.verbose, **kwargs
#    1032     )
#    1033     generation_info = final_chunk.generation_info
#    1034     chat_generation = ChatGeneration(
#    1035         message=AIMessage(
#    1036             content=final_chunk.text,
#    (...)   1043         generation_info=generation_info,
#    1044     )
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_ollama/chat_models.py:965, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     956 def _chat_stream_with_aggregation(
#     957     self,
#     958     messages: list[BaseMessage],
#    (...)    962     **kwargs: Any,
#     963 ) -> ChatGenerationChunk:
#     964     final_chunk = None
# --> 965     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#     966         if final_chunk is None:
#     967             final_chunk = chunk
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_ollama/chat_models.py:1054, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#    1047 def _iterate_over_stream(
#    1048     self,
#    1049     messages: list[BaseMessage],
#    1050     stop: list[str] | None = None,
#    1051     **kwargs: Any,
#    1052 ) -> Iterator[ChatGenerationChunk]:
#    1053     reasoning = kwargs.get("reasoning", self.reasoning)
# -> 1054     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#    1055         if not isinstance(stream_resp, str):
#    1056             content = (
#    1057                 stream_resp["message"]["content"]
#    1058                 if "message" in stream_resp and "content" in stream_resp["message"]
#    1059                 else ""
#    1060             )
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_ollama/chat_models.py:948, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     942 def _create_chat_stream(
#     943     self,
#     944     messages: list[BaseMessage],
#     945     stop: list[str] | None = None,
#     946     **kwargs: Any,
#     947 ) -> Iterator[Mapping[str, Any] | str]:
# --> 948     chat_params = self._chat_params(messages, stop, **kwargs)
#     950     if chat_params["stream"]:
#     951         if self._client:
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_ollama/chat_models.py:733, in ChatOllama._chat_params(self, messages, stop, **kwargs)
#     717 def _chat_params(
#     718     self,
#     719     messages: list[BaseMessage],
#     720     stop: list[str] | None = None,
#     721     **kwargs: Any,
#     722 ) -> dict[str, Any]:
#     723     """Assemble the parameters for a chat completion request.
#     724
#     725     Args:
#    (...)    731         A dictionary of parameters to pass to the Ollama client.
#     732     """
# --> 733     ollama_messages = self._convert_messages_to_ollama_messages(messages)
#     735     if self.stop is not None and stop is not None:
#     736         msg = "`stop` found in both the input and default params."
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_ollama/chat_models.py:904, in ChatOllama._convert_messages_to_ollama_messages(self, messages)
#     901         images.append(image_url_components[0])
#     902 elif is_data_content_block(content_part):
#     903     # Handles v1 "image" type
# --> 904     image = _get_image_from_data_content_block(content_part)
#     905     images.append(image)
#     906 else:
#
# File ~/Code/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_ollama/chat_models.py:250, in _get_image_from_data_content_block(block)
#     247     raise ValueError(error_message)
#     249 error_message = f"Blocks of type {block['type']} not supported."
# --> 250 raise ValueError(error_message)
#
# ValueError: Blocks of type audio not supported.
# During task with name 'model' and id 'ad6c75b0-37af-59d8-fbf7-9f998203dc97'
